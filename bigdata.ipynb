# %%
import numpy as np
volume_data = np.random.rand(1000000)
print("volume of data",len(volume_data))
# Out:
# volume of data 1000000

# %%
import time
for i in range(10):
    velocity_data = np.random.rand()
    print("velocitydata point:",velocity_data)
    time.sleep(2)
# Out:
# velocitydata point: 0.20186778439594577
# velocitydata point: 0.28440511458751805
# velocitydata point: 0.8213121632594296
# velocitydata point: 0.1615788034706096
# velocitydata point: 0.5850410892505451
# velocitydata point: 0.6615504688059606
# velocitydata point: 0.5999249611145325
# velocitydata point: 0.8710378452461356
# velocitydata point: 0.28064729847605496
# velocitydata point: 0.28615838134460714

# %%
stuctured_data = {'id': 1,'name': 'john','age': 30}
print(stuctured_data)
semi_stuctured_data = {'person':{'name':'Alice','age':25,'city':'new york'}}
unstuctured_data = "this is a sample text document. it can contain any infomation in free form "
# Out:
# {'id': 1, 'name': 'john', 'age': 30}

# %%
import random
veracity_data = [random.choice([1,2,3,None])for _ in range(20)]
print("veracity data:",veracity_data)
# Out:
# veracity data: [2, 3, 3, 3, 1, 1, None, 2, 1, 1, None, 3, 2, 2, None, 2, 3, 1, None, 2]
