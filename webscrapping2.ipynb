# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = "https://www.livemint.com/sports/cricket-news/icc-world-cup-points-table"

# %%
page = requests.get(url)

# %%
soup = BeautifulSoup(page.text,'html')
print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><meta content="width=device-width, user-scalable=yes" maximum-scale="1.0" name="viewport" user-scalable="no"/><meta content="no-referrer-when-downgrade" name="referrer"/><meta content="#ffffff" name="theme-color"/><meta content="59036276639-9ufea2catbasbmb6mmjn7kdsgpma6edn.apps.googleusercontent.com" name="google-signin-client_id"/><meta content="EwQFATcR7wbTZdv5oERLKcEEss7qLvsi494nTO6F-oA" name="google-site-verification"/><meta content="170844986298918" property="fb:pages"/><meta content="1395893943962978" property="fb:pages"/><link href="https://www.livemint.com/lm-img/icons/mintfavi.svg" rel="icon"/><title>ICC World Cup 2023 Points Table - Check ICC World Cup Standings &amp; Team Rankings</title><meta content="ICC World Cup 2023 Points Table: Get the latest updates on the World Cup 2023 points table and standings on Livemint. Find out the WC final 2023-24 ICC Cricket World Cup ranking, matches, wins, losses, and NRR for all the matches played." name="description"/><meta content="Cricket World Cup 2023 Points Table, ICC World Cup 2023 Points Table, Cricket World Cup Points Table, ICC World Cup 2023, ICC World Cup Points Table 2023" name="keywords"/><link href="https://www.livemint.com/sports/cricket-news/icc-world-cup-points-table" rel="canonical"/><meta content="en_us" property="og:locale"/><meta content="website" property="og:type"/><meta content="ICC World Cup 2023 Points Table - Check ICC World Cup Standings &amp; Team Rankings" property="og:title"/><meta content="ICC World Cup 2023 Points Table: Get the latest updates on the World Cup 2023 points table and standings on Livemint. Find out the WC final 2023-24 ICC Cricket World Cup ranking, matches, wins, losses, and NRR for all the matches played." property="og:description"/><meta content="https://www.livemint.com/sports/cricket-news/icc-world-cup-points-table" property="og:url"/><meta content="https://www.livemint.com/lm-img/static/default/newmintdefault-120.jpg" property="og:image"/><meta content="summary_large_image" name="twitter:card"/><meta content="@mint" name="twitter:site"/><meta content="@mint" name="twitter:creator"/><meta content="livemint.com" name="twitter:domain"/><meta content="index, follow" name="robots"/><meta content="https://www.livemint.com/sports/cricket-news/icc-world-cup-points-table" name="twitter:url"/><meta content="ICC World Cup 2023 Points Table - Check ICC World Cup Standings &amp; Team Rankings" name="twitter:title"/><meta content="ICC World Cup 2023 Points Table: Get the latest updates on the World Cup 2023 points table and standings on Livemint. Find out the WC final 2023-24 ICC Cricket World Cup ranking, matches, wins, losses, and NRR for all the matches played." name="twitter:description"/><meta content="https://www.livemint.com/lm-img/newschemalogo.png" name="twitter:image:src"/><script type="application/ld+json">{"@context":"https://schema.org","@type":"WebPage","name":"ICC World Cup 2023 Points Table - Check ICC World Cup Standings & Team Rankings","description":"ICC World Cup 2023 Points Table: Get the latest updates on the World Cup 2023 points table and standings on Livemint. Find out the WC final 2023-24 ICC Cricket World Cup ranking, matches, wins, losses, and NRR for all the matches played.","speakable":{"@type":"SpeakableSpecification","cssSelector":["h1"]},"url":"https://www.livemint.com/sports/cricket-news/icc-world-cup-points-table"}</script><script type="application/ld+json">{"@context":"https://schema.org","@type":"SiteNavigationElement","name":["News","Economy","Companies","Money","Markets","Elections 2024","Industry","Opinion","Technology","Lounge","Politics","Education","Sports"],"url":["/news","/economy","/companies","/money","/market","/elections","/industry","/opinion","/technology","/mint-lounge","/politics","/education","/sports"]}</script><script type="application/ld+json">{"@context":"https://schema.org","@type":"NewsMediaOrganization","name":"mint","url":"https://ww ...
# <br/></p><p>The Indian cricket team’s performance during the World Cup 2023 has been phenomenal. At present, the points table looks like this – India at the top with all 9 matches won and 18 points; followed by South Africa and Australia with 14 points each. So, India, South Africa, Australia and New Zealand have Qualified for Semi finals for ICC Cricket World Cup 2023.
# </p>
# <br/><p>The first semi-final is between India vs New Zealand on 15th Nov 2023 at Mumbai (Wankhede Stadium). 2nd Semi final will be played between South-africa vs Australia on 16th Nov 2023 at Kolkata (Eden Garden Stadium). Winners from Both teams will play the final on 19th Nov 2023 at Ahemadabad (Narendra Modi Stadium).
#
# </p>
# <br/><p>The points table serves as a critical marker throughout the event. It gives you a full rundown on how each team is faring, highlighting wins, losses, and the all-crucial Net Run Rate (NRR). If you're after real-time information on this significant aspect of the game, Livemint is a reliable go-to.</p>
# <br/><p>Think of the points table as a dynamic leaderboard, displaying each team's spot and accumulated points. Winning gets you two points, while a tied or abandoned match adds one. Losing? Well, that won't earn you points, but keep an eye on the NRR. It often breaks the tie when teams end up with the same points.
#
# <br/></p><p>In the round-robin stage, the focus is on face-to-face combat between teams, aiming for a spot in the knockout rounds. Success is important, but winning with a hefty margin can improve the NRR, an essential element in this high-stakes battle.</p>
# <br/><p>Livemint covers the ICC World Cup 2023 points table in depth. You can rely on us for the latest rankings, outcomes, and statistics on NRR. Our dedication to accuracy and prompt updates ensures that you're always in the know, whether you're an ardent follower or an occasional fan.</p>
# <br/><p>The ICC World Cup isn't just a line-up of matches; it's an emotional roller coaster uniting cricket aficionados globally. The points table is a living testament to each squad's hard graft, enthusiasm, and skill level. Seasoned cricket countries find pride in their standings while emerging teams see it as a stepping stone to greatness.</p>
# <br/><p>As the drama of the 2023 ICC World Cup continues to play out, consider Livemint your trusted ally for real-time points table and ranking updates. Stick with us to catch every twist and turn as cricket teams battle to carve their names into the history books.</p></div></div><a class="readMore">... <!-- --><span>Read More</span></a> <!-- --></div></div><div class="pointsCupSecHdg"><h2>World Cup Points Table 2024 <!-- -->- League<!-- --></h2></div><div class="customTblMain"><div class="customeTabl"><table class="tableFixed"><thead><tr><th>Pos</th><th>Teams</th></tr></thead><tbody><tr><td><strong>1<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/IND.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/india-4">ind</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/india-4">india</a></strong></div></td></tr><tr><td><strong>2<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/SA.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/south-africa-7">sa</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/south-africa-7">south africa</a></strong></div></td></tr><tr><td><strong>3<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/AUS.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/australia-1">aus</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/australia-1">australia</a></strong></div></td></tr><tr><td><strong>4<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/NZ.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/new-zealand-5">nz</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/new-zealand-5">new zealand</a></strong></div></td></tr><tr><td><strong>5<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/PAK.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/pakistan-6">pak</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/pakistan-6">pakistan</a></strong></div></td></tr><tr><td><strong>6<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/AFG.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/afghanistan-1188">afg</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/afghanistan-1188">afghanistan</a></strong></div></td></tr><tr><td><strong>7<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/ENG.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/england-3">eng</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/england-3">england</a></strong></div></td></tr><tr><td><strong>8<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/BAN.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/bangladesh-2">ban</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/bangladesh-2">bangladesh</a></strong></div></td></tr><tr><td><strong>9<!-- --></strong></td><td><div class="teamSection"><img alt="India ...

# %%
table = soup.find('table')
print(table)
# Out:
# <table class="tableFixed"><thead><tr><th>Pos</th><th>Teams</th></tr></thead><tbody><tr><td><strong>1<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/IND.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/india-4">ind</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/india-4">india</a></strong></div></td></tr><tr><td><strong>2<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/SA.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/south-africa-7">sa</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/south-africa-7">south africa</a></strong></div></td></tr><tr><td><strong>3<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/AUS.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/australia-1">aus</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/australia-1">australia</a></strong></div></td></tr><tr><td><strong>4<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/NZ.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/new-zealand-5">nz</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/new-zealand-5">new zealand</a></strong></div></td></tr><tr><td><strong>5<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/PAK.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/pakistan-6">pak</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/pakistan-6">pakistan</a></strong></div></td></tr><tr><td><strong>6<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/AFG.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/afghanistan-1188">afg</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/afghanistan-1188">afghanistan</a></strong></div></td></tr><tr><td><strong>7<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/ENG.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/england-3">eng</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/england-3">england</a></strong></div></td></tr><tr><td><strong>8<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/BAN.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/bangladesh-2">ban</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/bangladesh-2">bangladesh</a></strong></div></td></tr><tr><td><strong>9<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/SL.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/sri-lanka-8">sl</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/sri-lanka-8">sri lanka</a></strong></div></td></tr><tr><td><strong>10<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/NED.png?=v1"/> ...

# %%
Headings = table.find_all('th')
print(Headings)
# Out:
# [<th>Pos</th>, <th>Teams</th>]

# %%
Header = [i.text for i in Headings]
print(Header)
# Out:
# ['Pos', 'Teams']

# %%
df = pd.DataFrame(columns = Header)
df
# Out:
# Empty DataFrame
# Columns: [Pos, Teams]
# Index: []

# %%
rows = table.find_all('tr')
print(rows)
print(df.columns)
# Out:
# [<tr><th>Pos</th><th>Teams</th></tr>, <tr><td><strong>1<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/IND.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/india-4">ind</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/india-4">india</a></strong></div></td></tr>, <tr><td><strong>2<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/SA.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/south-africa-7">sa</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/south-africa-7">south africa</a></strong></div></td></tr>, <tr><td><strong>3<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/AUS.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/australia-1">aus</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/australia-1">australia</a></strong></div></td></tr>, <tr><td><strong>4<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/NZ.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/new-zealand-5">nz</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/new-zealand-5">new zealand</a></strong></div></td></tr>, <tr><td><strong>5<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/PAK.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/pakistan-6">pak</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/pakistan-6">pakistan</a></strong></div></td></tr>, <tr><td><strong>6<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/AFG.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/afghanistan-1188">afg</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/afghanistan-1188">afghanistan</a></strong></div></td></tr>, <tr><td><strong>7<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/ENG.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/england-3">eng</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/england-3">england</a></strong></div></td></tr>, <tr><td><strong>8<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/BAN.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/bangladesh-2">ban</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/bangladesh-2">bangladesh</a></strong></div></td></tr>, <tr><td><strong>9<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/SL.png?=v1"/><strong class="shortNam"><a href="https://www.hindustantimes.com/cricket/teams/sri-lanka-8">sl</a></strong><strong class="longNam"><a href="https://www.hindustantimes.com/cricket/teams/sri-lanka-8">sri lanka</a></strong></div></td></tr>, <tr><td><strong>10<!-- --></strong></td><td><div class="teamSection"><img alt="India" src="https://www.hindustantimes.com/static-content/1y/cricket-logos/teams/logo/NED.png?=v1"/><strong class="shortNam"><a ...
# Index(['Pos', 'Teams'], dtype='object')

# %%
ind = 0
for i in rows[1:10]:
  row_data = i.find_all('td')
  every_row_data = [i.text for i in row_data]
  print(every_row_data)
  df.loc[ind] = every_row_data
  ind = ind+1
# Out:
# ['1', 'indindia']
# ['2', 'sasouth africa']
# ['3', 'ausaustralia']
# ['4', 'nznew zealand']
# ['5', 'pakpakistan']
# ['6', 'afgafghanistan']
# ['7', 'engengland']
# ['8', 'banbangladesh']
# ['9', 'slsri lanka']

# %%
df
# Out:
#   Pos           Teams
# 0   1        indindia
# 1   2  sasouth africa
# 2   3    ausaustralia
# 3   4   nznew zealand
# 4   5     pakpakistan
# 5   6  afgafghanistan
# 6   7      engengland
# 7   8   banbangladesh
# 8   9     slsri lanka

# %%
df.to_csv("wc pointstable.csv")
